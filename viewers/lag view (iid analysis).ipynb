# %%
import pandas as pd
import numpy as np
from pandas.plotting import lag_plot

# %%
folder='../datasets'
filename='gold-prices.csv'
fname=f"{folder}/{filename}"
import os.path
os.path.isfile(fname)
# Out:
# True

# %%
df = pd.read_csv(fname, header=None, usecols=[0], names=['data'], 
                 thousands=',',dtype={'data':np.float64}, verbose=True)
# lineterminator=','  --> user for certain CSV files
# Out:
# Tokenization took: 0.69 ms
# Type conversion took: 0.62 ms
# Parser memory cleanup took: 0.01 ms

# %%
df
# Out:
#          data
# 0       226.0
# 1       226.0
# 2       226.8
# 3       218.6
# 4       223.2
# ...       ...
# 10611  1526.0
# 10612  1537.9
# 10613  1546.1
# 10614  1529.1
# 10615  1523.7
#
# [10616 rows x 1 columns]

# %%
df.plot.line()

# %%
lag_plot(df['data'])

# %%
lag_plot(np.log(df['data']))

# %%
lag_plot(df['data'], lag=2)

# %%
lag_plot(np.log(df['data']), lag=2)

# %%
lag_plot(df['data'], lag=4)

# %%
lag_plot(df['data'], lag=8)

# %%
lag_plot(df['data'], lag=16)

# %%
lag_plot(df['data'], lag=32)

# %%
# 
# Auto-correlation *relevant* only if stationary... 
#

# %%
lag1 = df.shift(periods=-1)

# %%
df.insert(1, "lag1", lag1)

# %%
df
# Out:
#          data    lag1
# 0       226.0   226.0
# 1       226.0   226.8
# 2       226.8   218.6
# 3       218.6   223.2
# 4       223.2   225.5
# ...       ...     ...
# 10611  1526.0  1537.9
# 10612  1537.9  1546.1
# 10613  1546.1  1529.1
# 10614  1529.1  1523.7
# 10615  1523.7     NaN
#
# [10616 rows x 2 columns]

# %%
df.corr()
# Out:
#          data     lag1
# data  1.00000  0.99978
# lag1  0.99978  1.00000
